# %%
import torch
import torch.nn as nn
import torch.utils.data as Data
import torchvision      
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
import sys

torch.manual_seed(1)    # reproducible
np.random.seed(seed = 1)

# Hyper Parameters
EPOCH = 50           
BATCH_SIZE = 1000
LR = 0.001

# %%
def random_select_data(array,ratio):
    selected_index = np.random.choice(array.shape[0],int(array.shape[0]/ratio),replace=False)
    array_selected = array[selected_index]
    return array_selected
def shuffle_along_axis(a, axis):
    np.random.seed(1)
    idx = np.random.rand(*a.shape).argsort(axis=axis)
    return np.take_along_axis(a,idx,axis=axis)

# %%
# Prepare training data and testing data
with open("termite_g2_scaffold_image_dict_scaffold19_size10660809_17_fragment.pickle", "rb") as handle:
    unserialized_training_data = pickle.load(handle)

# %%
# OPTION!!! Prepare random negative data
with open("termite_g2_scaffold_RANDOM_image_array_100000_17_2_10_fragment.pickle", "rb") as handle:
    random_negative_data = pickle.load(handle)

# %%
# Make training and testing data
temp_stack_array = np.concatenate([unserialized_training_data[x] for x in unserialized_training_data], 0)
#middle = (temp_stack_array.shape[2]-1)/2

#temp_stack_array_read_layer = temp_stack_array[:,1,32]
#temp_stack_array_read_layer[temp_stack_array_read_layer != 0].shape
temp_stack_array_label = np.zeros(temp_stack_array.shape[0])
for index in np.arange(0,temp_stack_array.shape[0]):
    if len(temp_stack_array[index,1,:][temp_stack_array[index,1,:] != 0]):
        temp_stack_array_label[index] = 1 
pos_array_ori = temp_stack_array[temp_stack_array_label == 1]
neg_array_ori = temp_stack_array[temp_stack_array_label == 0]

######## Make random selected negative data
#neg_array_ori_selected = random_select_data(neg_array_ori,4)

# OPTION!USE RANDOM DATA
neg_array_ori_selected = random_select_data(random_negative_data,1)
pos_array_ori = random_select_data(pos_array_ori,1)


print("Positive data: ", pos_array_ori.shape)
print("Negative data: ", neg_array_ori_selected.shape)
# Out:
# Positive data:  (99146, 2, 17)
# Negative data:  (100000, 2, 17)

# %%
POS_NEG_COMBINE_IMAGE = np.concatenate((pos_array_ori,neg_array_ori_selected),axis=0)
POS_LABEL = np.ones(pos_array_ori.shape[0])
NEG_LABEL = np.zeros(neg_array_ori_selected.shape[0])
POS_NEG_COMBINE_LABEL = np.concatenate((POS_LABEL,NEG_LABEL),axis=0)


POS_NEG_COMBINE_IMAGE_shuffle = shuffle_along_axis(POS_NEG_COMBINE_IMAGE, axis = 0)
POS_NEG_COMBINE_LABEL_shuffle = shuffle_along_axis(POS_NEG_COMBINE_LABEL, axis = 0)

# Separate training and testing data
X_train, X_test, y_train, y_test = train_test_split(POS_NEG_COMBINE_IMAGE_shuffle, POS_NEG_COMBINE_LABEL_shuffle, test_size=0.25, random_state=42)
X_train = np.expand_dims(X_train, axis=1)
X_test = np.expand_dims(X_test, axis=1)

print("Training image: ", X_train.shape)
print("Training label: ", y_train.shape)
print("Testing image: ", X_test.shape)
print("Testing label: ", y_test.shape)
# Out:
# Training image:  (149359, 1, 2, 17)
# Training label:  (149359,)
# Testing image:  (49787, 1, 2, 17)
# Testing label:  (49787,)

# %%
# Numpy to Torch
X_train_torch = torch.from_numpy(X_train)
X_test_torch = torch.from_numpy(X_test)
y_train_torch = torch.from_numpy(y_train)
y_test_torch = torch.from_numpy(y_test)

X_train_torch = X_train_torch.float()
y_train_torch = y_train_torch.long() 

X_test_torch = X_test_torch.float()
y_test_torch = y_test_torch.long()

print("Training image: ", X_train_torch.shape)
print("Training label: ", y_train_torch.shape)
print("Testing image: ", X_test_torch.shape)
print("Testing label: ", y_test_torch.shape)
# Out:
# Training image:  torch.Size([149359, 1, 2, 17])
# Training label:  torch.Size([149359])
# Testing image:  torch.Size([49787, 1, 2, 17])
# Testing label:  torch.Size([49787])

# %%
# Make batch
trainloader = torch.utils.data.DataLoader(X_train_torch, BATCH_SIZE, shuffle=False, num_workers=8) 
trainloader_label = torch.utils.data.DataLoader(y_train_torch, BATCH_SIZE, shuffle=False, num_workers=8)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(  # input shape (1, 28, 28) (1,2,65)
            nn.LayerNorm([2,17]),
            nn.Conv2d(
                in_channels=1,      # input height
                out_channels=8,    # n_filters
                kernel_size=1,      # filter size
                stride=1,           # filter movement/step
                padding=0,      #  padding=(kernel_size-1)/2 当 stride=1
            ),      # output shape (16, 28, 28)
            nn.ReLU(),    # activation
            #nn.MaxPool2d(kernel_size=2),    # output shape (16, 14, 14) (16,1,33)
        )
        self.conv2 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
            nn.Conv2d(8, 64, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
            nn.ReLU(),  # activation
            #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        self.conv3 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
            nn.Conv2d(64, 128, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
            nn.ReLU(),  # activation
            #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        self.conv4 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
        nn.Conv2d(128, 64, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
        nn.ReLU(),  # activation
        #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        self.conv5 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
        nn.Conv2d(64, 32, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
        nn.ReLU(),  # activation
        #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        
        self.out = nn.Linear(1088, 2)   # fully connected layer, output 10 classes

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = x.view(x.size(0), -1)   # (batch_size, 32 * 7 * 7)
        output = self.out(x)
        return output

cnn = CNN()
print(cnn)  # net architecture
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): LayerNorm((2, 17), eps=1e-05, elementwise_affine=True)
#     (1): Conv2d(1, 8, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv2d(8, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (conv5): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (out): Linear(in_features=1088, out_features=2, bias=True)
# )

# %%
import torch.nn.functional as F
optimizer = torch.optim.Adam(cnn.parameters(), lr=LR)   # optimize all cnn parameters

loss_func = nn.CrossEntropyLoss()   # the target label is not one-hotted
#loss_func = torch.nn.BCELoss(reduce=False, size_average=False)
#loss_func = torch.nn.NLLLoss(reduce=True, size_average=True)

correct = 0
total = 0
loss_list = []
accuracy_list = []
TP_list = []
TN_list = []
FP_list = []
FN_list = []


# training and testing
step_length = len(trainloader)

for epoch in range(EPOCH):
    print("epoch: ", epoch)
    LOSS = 0
    ACC = 0
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    sum_epoch = 0
    for step, (b_x, b_y) in enumerate(zip(trainloader, trainloader_label)):   
        processing = str(round(((step)/ step_length * 100),2)) + "%  " +"\r"
        sys.stdout.write(processing)
        sys.stdout.flush()
        
        
        
        output = cnn(b_x)               # cnn output
        loss = loss_func(output, b_y)   # cross entropy loss
        #loss = loss_func(F.sigmoid(output), b_y)
        optimizer.zero_grad()           # clear gradients for this training step
        loss.backward()                 # backpropagation, compute gradients
        optimizer.step()                # apply gradients
        
        pred_temp = torch.max(output, 1)[1].data.numpy().squeeze()
        LOSS += loss.item()
        b_y_numpy = b_y.numpy()
        sum_epoch += len(b_y)
        
        ACC += len(b_y_numpy[b_y_numpy == pred_temp])
        TP += sum((b_y_numpy == 1) & (pred_temp == 1))
        TN += sum((b_y_numpy == 0) & (pred_temp == 0))
        FP += sum((b_y_numpy == 0) & (pred_temp == 1))
        FN += sum((b_y_numpy == 1) & (pred_temp == 0))
        
        
    print("Loss in epoch", epoch," = ", LOSS/step_length)
    print("Accuracy in epoch", epoch," = ", ACC/sum_epoch)
    print("True positive: ", TP," / ",sum_epoch)
    print("True negative: ", TN," / ",sum_epoch)
    print("False positive: ", FP," / ",sum_epoch)
    print("False negative: ", FN," / ",sum_epoch)
    loss_list.append(LOSS/sum_epoch)
    accuracy_list.append(ACC/sum_epoch)
    TP_list.append(TP)
    TN_list.append(TN)
    FP_list.append(FP)
    FN_list.append(FN)
    
    print("=====================================================")
fig, ax1 = plt.subplots()
t = np.arange(0,EPOCH)

color = 'tab:red'
ax1.set_xlabel('epoch')
ax1.set_ylabel('loss', color=color)
ax1.plot(t, loss_list, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('accuracy(%)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, accuracy_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# epoch:  0
# Loss in epoch 0  =  0.6931907312075297
# Accuracy in epoch 0  =  0.5024002570986683
# True positive:  14465  /  149359
# True negative:  60573  /  149359
# False positive:  14483  /  149359
# False negative:  59838  /  149359
# =====================================================
# epoch:  1
# Loss in epoch 1  =  0.6931426397959392
# Accuracy in epoch 1  =  0.5026212012667466
# True positive:  7311  /  149359
# True negative:  67760  /  149359
# False positive:  7296  /  149359
# False negative:  66992  /  149359
# =====================================================
# epoch:  2
# Loss in epoch 2  =  0.693143001794815
# Accuracy in epoch 2  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  3
# Loss in epoch 3  =  0.6931426934401195
# Accuracy in epoch 3  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  4
# Loss in epoch 4  =  0.693142915169398
# Accuracy in epoch 4  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  5
# Loss in epoch 5  =  0.6931427856286366
# Accuracy in epoch 5  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  6
# Loss in epoch 6  =  0.6931426767508189
# Accuracy in epoch 6  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  7
# Loss in epoch 7  =  0.6931426290671031
# Accuracy in epoch 7  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  8
# Loss in epoch 8  =  0.6931427729129791
# Accuracy in epoch 8  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  9
# Loss in epoch 9  =  0.6931424367427826
# Accuracy in epoch 9  =  0.5017842915391774
# True positive:  13945  /  149359
# True negative:  61001  /  149359
# False positive:  14055  /  149359
# False negative:  60358  /  149359
# =====================================================
# epoch:  10
# Loss in epoch 10  =  0.6931426421801249
# Accuracy in epoch 10  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  11
# Loss in epoch 11  =  0.6931429735819499
# Accuracy in epoch 11  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  12
# Loss in epoch 12  =  0.6931430657704671
# Accuracy in epoch 12  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  13
# Loss in epoch 13  =  0.6931428706645966
# Accuracy in epoch 13  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  14
# Loss in epoch 14  =  0.6931430741151174
# Accuracy in epoch 14  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  15
# Loss in epoch 15  =  0.6931431929270426
# Accuracy in epoch 15  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  16
# Loss in epoch 16  =  0.6931432684262594
# Accuracy in epoch 16  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  17
# Loss in epoch 17  =  0.6931432950496673
# Accuracy in epoch 17  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  18
# Loss in epoch 18  =  0.693143192132314
# Accuracy in epoch 18  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  19
# Loss in epoch 19  =  0.6931431146462759
# Accuracy in epoch 19  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  20
# Loss in epoch 20  =  0.6931430439154307
# Accuracy in epoch 20  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  21
# Loss in epoch 21  =  0.6931430677572886
# Accuracy in epoch 21  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  22
# Loss in epoch 22  =  0.6931430705388387
# Accuracy in epoch 22  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  23
# Loss in epoch 23  =  0.6931431500116984
# Accuracy in epoch 23  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  24
# Loss in epoch 24  =  0.693143128156662
# Accuracy in epoch 24  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  25
# Loss in epoch 25  =  0.693143173456192
# Accuracy in epoch 25  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  26
# Loss in epoch 26  =  0.69314319729805
# Accuracy in epoch 26  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  27
# Loss in epoch 27  =  0.6931431134541829
# Accuracy in epoch 27  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  28
# Loss in epoch 28  =  0.693143204053243
# Accuracy in epoch 28  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  29
# Loss in epoch 29  =  0.6931432243188222
# Accuracy in epoch 29  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  30
# Loss in epoch 30  =  0.6931431833902995
# Accuracy in epoch 30  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  31
# Loss in epoch 31  =  0.6931432032585144
# Accuracy in epoch 31  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  32
# Loss in epoch 32  =  0.693143173456192
# Accuracy in epoch 32  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  33
# Loss in epoch 33  =  0.6931431877613068
# Accuracy in epoch 33  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  34
# Loss in epoch 34  =  0.693143272002538
# Accuracy in epoch 34  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  35
# Loss in epoch 35  =  0.6931433113416036
# Accuracy in epoch 35  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  36
# Loss in epoch 36  =  0.6931433049837749
# Accuracy in epoch 36  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  37
# Loss in epoch 37  =  0.6931432795524597
# Accuracy in epoch 37  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  38
# Loss in epoch 38  =  0.6931432783603668
# Accuracy in epoch 38  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  39
# Loss in epoch 39  =  0.6931432751814525
# Accuracy in epoch 39  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  40
# Loss in epoch 40  =  0.693143273194631
# Accuracy in epoch 40  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  41
# Loss in epoch 41  =  0.6931432656447093
# Accuracy in epoch 41  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  42
# Loss in epoch 42  =  0.6931432652473449
# Accuracy in epoch 42  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  43
# Loss in epoch 43  =  0.6931432616710663
# Accuracy in epoch 43  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  44
# Loss in epoch 44  =  0.6931432604789733
# Accuracy in epoch 44  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  45
# Loss in epoch 45  =  0.6931432608763377
# Accuracy in epoch 45  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  46
# Loss in epoch 46  =  0.6931432704130809
# Accuracy in epoch 46  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  47
# Loss in epoch 47  =  0.6931432704130809
# Accuracy in epoch 47  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  48
# Loss in epoch 48  =  0.6931432596842448
# Accuracy in epoch 48  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================
# epoch:  49
# Loss in epoch 49  =  0.6931432608763377
# Accuracy in epoch 49  =  0.5021726176527695
# True positive:  14474  /  149359
# True negative:  60530  /  149359
# False positive:  14526  /  149359
# False negative:  59829  /  149359
# =====================================================

# %%
# Out:
# 600

# %%
fig, ax = plt.subplots()
ax.plot(t, TP_list, 'b--', label= "True Positive")
ax.plot(t, TN_list, 'r:', label= "True Negative")
ax.plot(t, FP_list, 'r', label= "False Positive")
ax.plot(t, FN_list, "b", label= "False Negative")

legend = ax.legend(bbox_to_anchor=(1, 1), fontsize='x-large')

# Put a nicer background color on the legend.

plt.show()

# %%
60%11
# Out:
# 5
