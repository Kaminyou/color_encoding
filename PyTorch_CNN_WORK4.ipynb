# %%
import torch
import torch.nn as nn
import torch.utils.data as Data
import torchvision      
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
import sys

torch.manual_seed(1)    # reproducible
np.random.seed(seed = 1)

# Hyper Parameters
EPOCH = 50           
BATCH_SIZE = 500
LR = 0.0001

# %%
def random_select_data(array,ratio):
    selected_index = np.random.choice(array.shape[0],int(array.shape[0]/ratio),replace=False)
    array_selected = array[selected_index]
    return array_selected
def shuffle_along_axis(a, axis):
    np.random.seed(1)
    idx = np.random.rand(*a.shape).argsort(axis=axis)
    return np.take_along_axis(a,idx,axis=axis)

# %%
# Prepare training data and testing data
with open("termite_g2_scaffold_image_dict_scaffold19_size10660809_17_fragment.pickle", "rb") as handle:
    unserialized_training_data = pickle.load(handle)

# %%
# OPTION!!! Prepare random negative data
with open("termite_g2_scaffold_RANDOM_image_array_100000_17_2_10_fragment.pickle", "rb") as handle:
    random_negative_data = pickle.load(handle)

# %%
# Make training and testing data
temp_stack_array = np.concatenate([unserialized_training_data[x] for x in unserialized_training_data], 0)
#middle = (temp_stack_array.shape[2]-1)/2

#temp_stack_array_read_layer = temp_stack_array[:,1,32]
#temp_stack_array_read_layer[temp_stack_array_read_layer != 0].shape
temp_stack_array_label = np.zeros(temp_stack_array.shape[0])
for index in np.arange(0,temp_stack_array.shape[0]):
    if len(temp_stack_array[index,1,:][temp_stack_array[index,1,:] != 0]):
        temp_stack_array_label[index] = 1 
pos_array_ori = temp_stack_array[temp_stack_array_label == 1]
neg_array_ori = temp_stack_array[temp_stack_array_label == 0]

######## Make random selected negative data
#neg_array_ori_selected = random_select_data(neg_array_ori,4)

# OPTION!USE RANDOM DATA
neg_array_ori_selected = random_select_data(random_negative_data,1)
pos_array_ori = random_select_data(pos_array_ori,1)


print("Positive data: ", pos_array_ori.shape)
print("Negative data: ", neg_array_ori_selected.shape)
# Out:
# Positive data:  (99146, 2, 17)
# Negative data:  (100000, 2, 17)

# %%
POS_NEG_COMBINE_IMAGE = np.concatenate((pos_array_ori,neg_array_ori_selected),axis=0)
POS_LABEL = np.ones(pos_array_ori.shape[0])
NEG_LABEL = np.zeros(neg_array_ori_selected.shape[0])
POS_NEG_COMBINE_LABEL = np.concatenate((POS_LABEL,NEG_LABEL),axis=0)


POS_NEG_COMBINE_IMAGE_shuffle = shuffle_along_axis(POS_NEG_COMBINE_IMAGE, axis = 0)
POS_NEG_COMBINE_LABEL_shuffle = shuffle_along_axis(POS_NEG_COMBINE_LABEL, axis = 0)

# Separate training and testing data
X_train, X_test, y_train, y_test = train_test_split(POS_NEG_COMBINE_IMAGE_shuffle, POS_NEG_COMBINE_LABEL_shuffle, test_size=0.25, random_state=42)
X_train = np.expand_dims(X_train, axis=1)
X_test = np.expand_dims(X_test, axis=1)

print("Training image: ", X_train.shape)
print("Training label: ", y_train.shape)
print("Testing image: ", X_test.shape)
print("Testing label: ", y_test.shape)
# Out:
# Training image:  (149359, 1, 2, 17)
# Training label:  (149359,)
# Testing image:  (49787, 1, 2, 17)
# Testing label:  (49787,)

# %%
# Numpy to Torch
X_train_torch = torch.from_numpy(X_train)
X_test_torch = torch.from_numpy(X_test)
y_train_torch = torch.from_numpy(y_train)
y_test_torch = torch.from_numpy(y_test)

X_train_torch = X_train_torch.float()
y_train_torch = y_train_torch.long() 

X_test_torch = X_test_torch.float()
y_test_torch = y_test_torch.long()

print("Training image: ", X_train_torch.shape)
print("Training label: ", y_train_torch.shape)
print("Testing image: ", X_test_torch.shape)
print("Testing label: ", y_test_torch.shape)
# Out:
# Training image:  torch.Size([149359, 1, 2, 17])
# Training label:  torch.Size([149359])
# Testing image:  torch.Size([49787, 1, 2, 17])
# Testing label:  torch.Size([49787])

# %%
# Make batch
trainloader = torch.utils.data.DataLoader(X_train_torch, BATCH_SIZE, shuffle=False, num_workers=8) 
trainloader_label = torch.utils.data.DataLoader(y_train_torch, BATCH_SIZE, shuffle=False, num_workers=8)

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(  # input shape (1, 28, 28) (1,2,65)
            nn.Conv2d(
                in_channels=1,      # input height
                out_channels=128,    # n_filters
                kernel_size=1,      # filter size
                stride=1,           # filter movement/step
                padding=0,      #  padding=(kernel_size-1)/2 当 stride=1
            ),      # output shape (16, 28, 28)
            nn.ReLU(),    # activation
            #nn.MaxPool2d(kernel_size=2),    # output shape (16, 14, 14) (16,1,33)
        )
        self.conv2 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
            nn.Conv2d(128, 512, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
            nn.ReLU(),  # activation
            #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        self.conv3 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
            nn.Conv2d(512, 2048, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
            nn.ReLU(),  # activation
            #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        self.conv4 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
        nn.Conv2d(2048, 512, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
        nn.ReLU(),  # activation
        #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        self.conv5 = nn.Sequential(  # input shape (16, 14, 14) (16,1,33)
        nn.Conv2d(512, 128, 1, 1, padding=0),  # output shape (32, 14, 14) (32,1,33)
        nn.ReLU(),  # activation
        #nn.MaxPool2d(2),  # output shape (32, 7, 7)
        )
        
        self.out = nn.Linear(4352, 2)   # fully connected layer, output 10 classes

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = x.view(x.size(0), -1)   # (batch_size, 32 * 7 * 7)
        output = self.out(x)
        return output

cnn = CNN()
print(cnn)  # net architecture
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(1, 128, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (conv2): Sequential(
#     (0): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (conv3): Sequential(
#     (0): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (conv4): Sequential(
#     (0): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (conv5): Sequential(
#     (0): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#     (1): ReLU()
#   )
#   (out): Linear(in_features=4352, out_features=2, bias=True)
# )

# %%
import torch.nn.functional as F
optimizer = torch.optim.Adam(cnn.parameters(), lr=LR)   # optimize all cnn parameters

loss_func = nn.CrossEntropyLoss()   # the target label is not one-hotted
#loss_func = torch.nn.BCELoss(reduce=False, size_average=False)
#loss_func = torch.nn.NLLLoss(reduce=True, size_average=True)

correct = 0
total = 0
loss_list = []
accuracy_list = []
TP_list = []
TN_list = []
FP_list = []
FN_list = []


# training and testing
step_length = len(trainloader)

for epoch in range(EPOCH):
    print("epoch: ", epoch)
    LOSS = 0
    ACC = 0
    TP = 0
    TN = 0
    FP = 0
    FN = 0
    sum_epoch = 0
    for step, (b_x, b_y) in enumerate(zip(trainloader, trainloader_label)):   
        processing = str(round(((step)/ step_length * 100),2)) + "%" +"\r"
        sys.stdout.write(processing)
        sys.stdout.flush()
        
        
        
        output = cnn(b_x)               # cnn output
        loss = loss_func(output, b_y)   # cross entropy loss
        #loss = loss_func(F.sigmoid(output), b_y)
        optimizer.zero_grad()           # clear gradients for this training step
        loss.backward()                 # backpropagation, compute gradients
        optimizer.step()                # apply gradients
        
        pred_temp = torch.max(output, 1)[1].data.numpy().squeeze()
        LOSS += loss.item()
        b_y_numpy = b_y.numpy()
        sum_epoch += len(b_y)
        
        ACC += len(b_y_numpy[b_y_numpy == pred_temp])
        TP += sum((b_y_numpy == 1) & (pred_temp == 1))
        TN += sum((b_y_numpy == 0) & (pred_temp == 0))
        FP += sum((b_y_numpy == 0) & (pred_temp == 1))
        FN += sum((b_y_numpy == 1) & (pred_temp == 0))
        
        
    print("Loss in epoch", epoch," = ", LOSS/step_length)
    print("Accuracy in epoch", epoch," = ", ACC/sum_epoch)
    print("True positive: ", TP," / ",sum_epoch)
    print("True negative: ", TN," / ",sum_epoch)
    print("False positive: ", FP," / ",sum_epoch)
    print("False negative: ", FN," / ",sum_epoch)
    loss_list.append(LOSS/sum_epoch)
    accuracy_list.append(ACC/sum_epoch)
    TP_list.append(TP)
    TN_list.append(TN)
    FP_list.append(FP)
    FN_list.append(FN)
    
    print("=====================================================")
fig, ax1 = plt.subplots()
t = np.arange(0,EPOCH)

color = 'tab:red'
ax1.set_xlabel('epoch')
ax1.set_ylabel('loss', color=color)
ax1.plot(t, loss_list, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('accuracy(%)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, accuracy_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# epoch:  0
# Loss in epoch 0  =  0.7094761266756218
# Accuracy in epoch 0  =  0.5008536479221205
# True positive:  35318  /  149359
# True negative:  39489  /  149359
# False positive:  35567  /  149359
# False negative:  38985  /  149359
# =====================================================
# epoch:  1
# Loss in epoch 1  =  0.6931838066282878
# Accuracy in epoch 1  =  0.5018512443173829
# True positive:  31662  /  149359
# True negative:  43294  /  149359
# False positive:  31762  /  149359
# False negative:  42641  /  149359
# =====================================================
# epoch:  2
# Loss in epoch 2  =  0.69313041741234
# Accuracy in epoch 2  =  0.5019784545959735
# True positive:  26768  /  149359
# True negative:  48207  /  149359
# False positive:  26849  /  149359
# False negative:  47535  /  149359
# =====================================================
# epoch:  3
# Loss in epoch 3  =  0.6931194025138548
# Accuracy in epoch 3  =  0.5034581109943157
# True positive:  22871  /  149359
# True negative:  52325  /  149359
# False positive:  22731  /  149359
# False negative:  51432  /  149359
# =====================================================
# epoch:  4
# Loss in epoch 4  =  0.6933046378020857
# Accuracy in epoch 4  =  0.5029626604355948
# True positive:  26001  /  149359
# True negative:  49121  /  149359
# False positive:  25935  /  149359
# False negative:  48302  /  149359
# =====================================================
# epoch:  5
# Loss in epoch 5  =  0.6932536899844141
# Accuracy in epoch 5  =  0.5033911582161101
# True positive:  27527  /  149359
# True negative:  47659  /  149359
# False positive:  27397  /  149359
# False negative:  46776  /  149359
# =====================================================
# epoch:  6
# Loss in epoch 6  =  0.693104355430922
# Accuracy in epoch 6  =  0.5043284971109876
# True positive:  20112  /  149359
# True negative:  55214  /  149359
# False positive:  19842  /  149359
# False negative:  54191  /  149359
# =====================================================
# epoch:  7
# Loss in epoch 7  =  0.693094364775463
# Accuracy in epoch 7  =  0.5043753640557315
# True positive:  21864  /  149359
# True negative:  53469  /  149359
# False positive:  21587  /  149359
# False negative:  52439  /  149359
# =====================================================
# epoch:  8
# Loss in epoch 8  =  0.6930938805624792
# Accuracy in epoch 8  =  0.505192187949839
# True positive:  25423  /  149359
# True negative:  50032  /  149359
# False positive:  25024  /  149359
# False negative:  48880  /  149359
# =====================================================
# epoch:  9
# Loss in epoch 9  =  0.6930974189653045
# Accuracy in epoch 9  =  0.5061630032338192
# True positive:  24251  /  149359
# True negative:  51349  /  149359
# False positive:  23707  /  149359
# False negative:  50052  /  149359
# =====================================================
# epoch:  10
# Loss in epoch 10  =  0.6931369007630491
# Accuracy in epoch 10  =  0.5049109862813758
# True positive:  24417  /  149359
# True negative:  50996  /  149359
# False positive:  24060  /  149359
# False negative:  49886  /  149359
# =====================================================
# epoch:  11
# Loss in epoch 11  =  0.693066865903478
# Accuracy in epoch 11  =  0.5051988832276595
# True positive:  23914  /  149359
# True negative:  51542  /  149359
# False positive:  23514  /  149359
# False negative:  50389  /  149359
# =====================================================
# epoch:  12
# Loss in epoch 12  =  0.6931585894779219
# Accuracy in epoch 12  =  0.5047034326689386
# True positive:  23694  /  149359
# True negative:  51688  /  149359
# False positive:  23368  /  149359
# False negative:  50609  /  149359
# =====================================================
# epoch:  13
# Loss in epoch 13  =  0.6930492980823071
# Accuracy in epoch 13  =  0.5048641193366319
# True positive:  23373  /  149359
# True negative:  52033  /  149359
# False positive:  23023  /  149359
# False negative:  50930  /  149359
# =====================================================
# epoch:  14
# Loss in epoch 14  =  0.6930473129884854
# Accuracy in epoch 14  =  0.504743604335862
# True positive:  22491  /  149359
# True negative:  52897  /  149359
# False positive:  22159  /  149359
# False negative:  51812  /  149359
# =====================================================
# epoch:  15
# Loss in epoch 15  =  0.6930451432996769
# Accuracy in epoch 15  =  0.5043954498891932
# True positive:  22480  /  149359
# True negative:  52856  /  149359
# False positive:  22200  /  149359
# False negative:  51823  /  149359
# =====================================================
# epoch:  16
# Loss in epoch 16  =  0.6930426428947959
# Accuracy in epoch 16  =  0.5045360507234248
# True positive:  22266  /  149359
# True negative:  53091  /  149359
# False positive:  21965  /  149359
# False negative:  52037  /  149359
# =====================================================
# epoch:  17
# Loss in epoch 17  =  0.6930483611531082
# Accuracy in epoch 17  =  0.5046632610020153
# True positive:  23146  /  149359
# True negative:  52230  /  149359
# False positive:  22826  /  149359
# False negative:  51157  /  149359
# =====================================================
# epoch:  18
# Loss in epoch 18  =  0.6930401773755765
# Accuracy in epoch 18  =  0.504368668777911
# True positive:  22666  /  149359
# True negative:  52666  /  149359
# False positive:  22390  /  149359
# False negative:  51637  /  149359
# =====================================================
# epoch:  19
# Loss in epoch 19  =  0.6930375790914963
# Accuracy in epoch 19  =  0.5044557073895781
# True positive:  22148  /  149359
# True negative:  53197  /  149359
# False positive:  21859  /  149359
# False negative:  52155  /  149359
# =====================================================
# epoch:  20
# Loss in epoch 20  =  0.693040255918152
# Accuracy in epoch 20  =  0.5051386257272745
# True positive:  22110  /  149359
# True negative:  53337  /  149359
# False positive:  21719  /  149359
# False negative:  52193  /  149359
# =====================================================
# epoch:  21
# Loss in epoch 21  =  0.6930490397290642
# Accuracy in epoch 21  =  0.5044958790565014
# True positive:  20862  /  149359
# True negative:  54489  /  149359
# False positive:  20567  /  149359
# False negative:  53441  /  149359
# =====================================================
# epoch:  22
# Loss in epoch 22  =  0.6930849247154185
# Accuracy in epoch 22  =  0.504502574334322
# True positive:  21210  /  149359
# True negative:  54142  /  149359
# False positive:  20914  /  149359
# False negative:  53093  /  149359
# =====================================================
# epoch:  23
# Loss in epoch 23  =  0.6930422047308855
# Accuracy in epoch 23  =  0.5048507287809908
# True positive:  20118  /  149359
# True negative:  55286  /  149359
# False positive:  19770  /  149359
# False negative:  54185  /  149359
# =====================================================
# epoch:  24
# Loss in epoch 24  =  0.6930375448038746
# Accuracy in epoch 24  =  0.504817252391888
# True positive:  21357  /  149359
# True negative:  54042  /  149359
# False positive:  21014  /  149359
# False negative:  52946  /  149359
# =====================================================
# epoch:  25
# Loss in epoch 25  =  0.6932456367789304
# Accuracy in epoch 25  =  0.5047034326689386
# True positive:  19631  /  149359
# True negative:  55751  /  149359
# False positive:  19305  /  149359
# False negative:  54672  /  149359
# =====================================================
# epoch:  26
# Loss in epoch 26  =  0.6930526702300362
# Accuracy in epoch 26  =  0.5038397418300873
# True positive:  18867  /  149359
# True negative:  56386  /  149359
# False positive:  18670  /  149359
# False negative:  55436  /  149359
# =====================================================
# epoch:  27
# Loss in epoch 27  =  0.6930452425743027
# Accuracy in epoch 27  =  0.5044958790565014
# True positive:  20104  /  149359
# True negative:  55247  /  149359
# False positive:  19809  /  149359
# False negative:  54199  /  149359
# =====================================================
# epoch:  28
# Loss in epoch 28  =  0.6930414019619741
# Accuracy in epoch 28  =  0.504562831834707
# True positive:  21262  /  149359
# True negative:  54099  /  149359
# False positive:  20957  /  149359
# False negative:  53041  /  149359
# =====================================================
# epoch:  29
# Loss in epoch 29  =  0.6930423444728787
# Accuracy in epoch 29  =  0.5053060076727884
# True positive:  19509  /  149359
# True negative:  55963  /  149359
# False positive:  19093  /  149359
# False negative:  54794  /  149359
# =====================================================
# epoch:  30
# Loss in epoch 30  =  0.6930411392231052
# Accuracy in epoch 30  =  0.5047168232245797
# True positive:  20492  /  149359
# True negative:  54892  /  149359
# False positive:  20164  /  149359
# False negative:  53811  /  149359
# =====================================================
# epoch:  31
# Loss in epoch 31  =  0.6930376141765046
# Accuracy in epoch 31  =  0.5049377673926579
# True positive:  20699  /  149359
# True negative:  54718  /  149359
# False positive:  20338  /  149359
# False negative:  53604  /  149359
# =====================================================
# epoch:  32
# Loss in epoch 32  =  0.6930590690577708
# Accuracy in epoch 32  =  0.5045226601677837
# True positive:  21493  /  149359
# True negative:  53862  /  149359
# False positive:  21194  /  149359
# False negative:  52810  /  149359
# =====================================================
# epoch:  33
# Loss in epoch 33  =  0.6930442526188981
# Accuracy in epoch 33  =  0.5048373382253497
# True positive:  19760  /  149359
# True negative:  55642  /  149359
# False positive:  19414  /  149359
# False negative:  54543  /  149359
# =====================================================
# epoch:  34
# Loss in epoch 34  =  0.6930368143977927
# Accuracy in epoch 34  =  0.5044757932230398
# True positive:  20961  /  149359
# True negative:  54387  /  149359
# False positive:  20669  /  149359
# False negative:  53342  /  149359
# =====================================================
# epoch:  35
# Loss in epoch 35  =  0.6931363356153303
# Accuracy in epoch 35  =  0.5041678104432944
# True positive:  19694  /  149359
# True negative:  55608  /  149359
# False positive:  19448  /  149359
# False negative:  54609  /  149359
# =====================================================
# epoch:  36
# Loss in epoch 36  =  0.6930356817101954
# Accuracy in epoch 36  =  0.5055537329521489
# True positive:  20874  /  149359
# True negative:  54635  /  149359
# False positive:  20421  /  149359
# False negative:  53429  /  149359
# =====================================================
# epoch:  37
# Loss in epoch 37  =  0.6930541063232166
# Accuracy in epoch 37  =  0.5051118446159923
# True positive:  21639  /  149359
# True negative:  53804  /  149359
# False positive:  21252  /  149359
# False negative:  52664  /  149359
# =====================================================
# epoch:  38
# Loss in epoch 38  =  0.69303200456211
# Accuracy in epoch 38  =  0.5051386257272745
# True positive:  22004  /  149359
# True negative:  53443  /  149359
# False positive:  21613  /  149359
# False negative:  52299  /  149359
# =====================================================
# epoch:  39
# Loss in epoch 39  =  0.6930319441600786
# Accuracy in epoch 39  =  0.5051252351716334
# True positive:  21328  /  149359
# True negative:  54117  /  149359
# False positive:  20939  /  149359
# False negative:  52975  /  149359
# =====================================================
# epoch:  40
# Loss in epoch 40  =  0.6930277732303709
# Accuracy in epoch 40  =  0.5051520162829156
# True positive:  21048  /  149359
# True negative:  54401  /  149359
# False positive:  20655  /  149359
# False negative:  53255  /  149359
# =====================================================
# epoch:  41
# Loss in epoch 41  =  0.693025243521534
# Accuracy in epoch 41  =  0.5056742479529188
# True positive:  21607  /  149359
# True negative:  53920  /  149359
# False positive:  21136  /  149359
# False negative:  52696  /  149359
# =====================================================
# epoch:  42
# Loss in epoch 42  =  0.6930232468656075
# Accuracy in epoch 42  =  0.5054800848961227
# True positive:  21747  /  149359
# True negative:  53751  /  149359
# False positive:  21305  /  149359
# False negative:  52556  /  149359
# =====================================================
# epoch:  43
# Loss in epoch 43  =  0.6930192748838444
# Accuracy in epoch 43  =  0.5056206857303543
# True positive:  21773  /  149359
# True negative:  53746  /  149359
# False positive:  21310  /  149359
# False negative:  52530  /  149359
# =====================================================
# epoch:  44
# Loss in epoch 44  =  0.6930265025949
# Accuracy in epoch 44  =  0.5049980248930429
# True positive:  21633  /  149359
# True negative:  53793  /  149359
# False positive:  21263  /  149359
# False negative:  52670  /  149359
# =====================================================
# epoch:  45
# Loss in epoch 45  =  0.6930178896240566
# Accuracy in epoch 45  =  0.5051787973941979
# True positive:  21128  /  149359
# True negative:  54325  /  149359
# False positive:  20731  /  149359
# False negative:  53175  /  149359
# =====================================================
# epoch:  46
# Loss in epoch 46  =  0.69301633412224
# Accuracy in epoch 46  =  0.5054800848961227
# True positive:  21691  /  149359
# True negative:  53807  /  149359
# False positive:  21249  /  149359
# False negative:  52612  /  149359
# =====================================================
# epoch:  47
# Loss in epoch 47  =  0.6930155801932548
# Accuracy in epoch 47  =  0.5053060076727884
# True positive:  21818  /  149359
# True negative:  53654  /  149359
# False positive:  21402  /  149359
# False negative:  52485  /  149359
# =====================================================
# epoch:  48
# Loss in epoch 48  =  0.6930396800057147
# Accuracy in epoch 48  =  0.5053796557288145
# True positive:  21936  /  149359
# True negative:  53547  /  149359
# False positive:  21509  /  149359
# False negative:  52367  /  149359
# =====================================================
# epoch:  49
# Loss in epoch 49  =  0.6930127243533182
# Accuracy in epoch 49  =  0.5051988832276595
# True positive:  21652  /  149359
# True negative:  53804  /  149359
# False positive:  21252  /  149359
# False negative:  52651  /  149359
# =====================================================

# %%
fig, ax = plt.subplots()
ax.plot(t, TP_list, 'b--', label= "True Positive")
ax.plot(t, TN_list, 'r:', label= "True Negative")
ax.plot(t, FP_list, 'r', label= "False Positive")
ax.plot(t, FN_list, "b", label= "False Negative")

legend = ax.legend(bbox_to_anchor=(1, 1), fontsize='x-large')

# Put a nicer background color on the legend.

plt.show()

# %%
fig, ax1 = plt.subplots()
t = np.arange(0,40)

color = 'tab:red'
ax1.set_xlabel('epoch')
ax1.set_ylabel('loss', color=color)
ax1.plot(t, loss_list, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('accuracy(%)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, accuracy_list, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
